# %%
import pandas as pd
pot = 'csv/'
datoteka =  'metal_skupine_id.csv'
celotna_tabela = pd.read_csv(datoteka)

# %%
celotna_tabela[['ime', 'leto']]
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:1: FutureWarning: sort(....) is deprecated, use sort_index(.....)
#   if __name__ == '__main__':
#                              ime    leto
# 0                      Hatebreed  1994.0
# 1                       Slipknot  1995.0
# 2                           Korn  1993.0
# 3                      Biohazard  1987.0
# 4                    Limp Bizkit  1994.0
# 5      Between the Buried and Me  2000.0
# 6                      Rammstein  1994.0
# 7        Bullet for My Valentine  1993.0
# 8                       Converge  1990.0
# 9                       Skindred  1998.0
# 10       Five Finger Death Punch  2005.0
# 11              System of a Down  1994.0
# 12                 Drowning Pool  1996.0
# 13                     TesseracT  2003.0
# 14              Jeff Killed John  1998.0
# 15                         Brawl  1994.0
# 16                      Amorphis  1990.0
# 17                Blind Guardian  1986.0
# ...
